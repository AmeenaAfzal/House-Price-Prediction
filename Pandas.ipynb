# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: C:\Users\WIN-11\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
s=pd.Series([1,2,3])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
data={"Name":["Ann","Anu"],"Age":[10,12]}
df=pd.DataFrame(data)
print(df)
# Out:
#   Name  Age
# 0  Ann   10
# 1  Anu   12

# %%
df=pd.read_csv("global_placement.csv")
display(df)
df.to_csv("output.csv",index=False)
display(df.head())
display(df.tail())
display(df.info())
display(df.describe())
display(df["cgpa"],df["college_tier"])
print(df.loc[0])
print(df.iloc[0])
# Out:
#           cgpa  backlogs college_tier  country university_ranking_band  \
# 0     7.397371         1       Tier 2   Canada                 100-300
# 1     6.889389         0       Tier 3       UK                    300+
# 2     7.518151         0       Tier 1       UK                 100-300
# 3     8.218424         0       Tier 2       UK                 100-300
# 4     6.812677         1       Tier 2      USA                 100-300
# ...        ...       ...          ...      ...                     ...
# 9995  8.040882         0       Tier 3      USA                 100-300
# 9996  5.401324         3       Tier 1       UK                 100-300
# 9997  6.435747         0       Tier 3       UK                    300+
# 9998  7.396612         1       Tier 3  Germany                 100-300
# 9999  7.515511         3       Tier 2       UK                    300+
#
#       internship_count  aptitude_score  communication_score specialization  \
# ...
