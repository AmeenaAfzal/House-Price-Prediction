# %% [markdown]
# print("Hiii")

# %% [markdown]
# # python

# %%
a=int(input("enter no 1"))
b=int(input("enter no 2"))
c=a+b
print(c,"is added no")
# Out:
# enter no 1  4
# enter no 2  5
# 9 is added no

# %%
a=int(input("enter number"))
if a%2==0:
    print(a,"is even")
else:
    print(a,"is odd")
# Out:
# enter number 2
# 2 is even

# %%
for i in range (1,5):
    print("*"*i,"\n")
# Out:
# *
#
# **
#
# ***
#
# ****

# %%
def callperson(name):
    print("Hello",name)
callperson("Anusha")
# Out:
# Hello Anusha
